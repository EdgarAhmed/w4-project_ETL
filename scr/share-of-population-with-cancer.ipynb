# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select   # seleccion de un dropdown
import time
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver import ActionChains #para mover las barras
import asyncio as asy
from tqdm.notebook import tqdm
import numpy as np  #Numpy
import matplotlib.pyplot as plt #graficas

# %%
df_1 = pd.read_csv('/Users/edgarahmed/Desktop/ironhack/semana_4/dia_5/w4-project_ETL/data/share-of-population-with-cancer.csv')


df_1
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1990
# 1     Afghanistan  AFG  1991
# 2     Afghanistan  AFG  1992
# 3     Afghanistan  AFG  1993
# 4     Afghanistan  AFG  1994
# ...           ...  ...   ...
# 6775     Zimbabwe  ZWE  2015
# 6776     Zimbabwe  ZWE  2016
# 6777     Zimbabwe  ZWE  2017
# 6778     Zimbabwe  ZWE  2018
# 6779     Zimbabwe  ZWE  2019
#
#       Current number of cases of neoplasms per 100 people, in both sexes aged age-standardized
# 0                                              9.494158
# 1                                              9.484262
# 2                                              9.473225
# 3                                              9.468410
# 4                                              9.466758
# ...                                                 ...
# 6775                                           8.956846
# 6776                                           8.962681
# 6777                                           8.963917
# 6778                                           8.963226
# 6779                                           8.964857
#
# [6780 rows x 4 columns]

# %%
df_cases = df_1.copy()

df_cases
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1990
# 1     Afghanistan  AFG  1991
# 2     Afghanistan  AFG  1992
# 3     Afghanistan  AFG  1993
# 4     Afghanistan  AFG  1994
# ...           ...  ...   ...
# 6775     Zimbabwe  ZWE  2015
# 6776     Zimbabwe  ZWE  2016
# 6777     Zimbabwe  ZWE  2017
# 6778     Zimbabwe  ZWE  2018
# 6779     Zimbabwe  ZWE  2019
#
#       Current number of cases of neoplasms per 100 people, in both sexes aged age-standardized
# 0                                              9.494158
# 1                                              9.484262
# 2                                              9.473225
# 3                                              9.468410
# 4                                              9.466758
# ...                                                 ...
# 6775                                           8.956846
# 6776                                           8.962681
# 6777                                           8.963917
# 6778                                           8.963226
# 6779                                           8.964857
#
# [6780 rows x 4 columns]

# %%
df_cases.columns
# Out:
# Index(['Entity', 'Code', 'Year',
#        'Current number of cases of neoplasms per 100 people, in both sexes aged age-standardized'],
#       dtype='object')

# %%
new_col_name = ['Country', 'Code', 'Year', 'Number_cases_100']

# %%
df_cases.columns = new_col_name

df_cases
# Out:
#           Country Code  Year  Number_cases_100
# 0     Afghanistan  AFG  1990          9.494158
# 1     Afghanistan  AFG  1991          9.484262
# 2     Afghanistan  AFG  1992          9.473225
# 3     Afghanistan  AFG  1993          9.468410
# 4     Afghanistan  AFG  1994          9.466758
# ...           ...  ...   ...               ...
# 6775     Zimbabwe  ZWE  2015          8.956846
# 6776     Zimbabwe  ZWE  2016          8.962681
# 6777     Zimbabwe  ZWE  2017          8.963917
# 6778     Zimbabwe  ZWE  2018          8.963226
# 6779     Zimbabwe  ZWE  2019          8.964857
#
# [6780 rows x 4 columns]

# %%
df_cases_4 = df_cases[df_cases['Code'].isin(['ESP', 'FRA', 'USA', 'GBR'])]

df_cases_4
# Out:
#             Country Code  Year  Number_cases_100
# 2100         France  FRA  1990          7.583686
# 2101         France  FRA  1991          7.604560
# 2102         France  FRA  1992          7.632786
# 2103         France  FRA  1993          7.662681
# 2104         France  FRA  1994          7.678130
# ...             ...  ...   ...               ...
# 6415  United States  USA  2015          5.326545
# 6416  United States  USA  2016          5.356023
# 6417  United States  USA  2017          5.381902
# 6418  United States  USA  2018          5.445825
# 6419  United States  USA  2019          5.545537
#
# [120 rows x 4 columns]

# %%
# 6405  United States  USA  2005          5.160140
# 6406  United States  USA  2006          5.155525
# 6407  United States  USA  2007          5.175234
# 6408  United States  USA  2008          5.218645
# 6409  United States  USA  2009          5.265043
# 6410  United States  USA  2010          5.285463
# 6411  United States  USA  2011          5.304242
# 6412  United States  USA  2012          5.310717
# 6413  United States  USA  2013          5.315775
# 6414  United States  USA  2014          5.318676
# 6415  United States  USA  2015          5.326545
# 6416  United States  USA  2016          5.356023
# 6417  United States  USA  2017          5.381902
# 6418  United States  USA  2018          5.445825
# 6419  United States  USA  2019          5.545537

# %%
df_cases_4_uk = df_cases_4[df_cases_4['Code'].isin(['GBR'])]

df_cases_4_uk
# Out:
#              Country Code  Year  Number_cases_100
# 6360  United Kingdom  GBR  1990          6.775162
# 6361  United Kingdom  GBR  1991          6.626050
# 6362  United Kingdom  GBR  1992          6.490878
# 6363  United Kingdom  GBR  1993          6.390253
# 6364  United Kingdom  GBR  1994          6.303621
# 6365  United Kingdom  GBR  1995          6.275422
# 6366  United Kingdom  GBR  1996          6.267869
# 6367  United Kingdom  GBR  1997          6.264924
# 6368  United Kingdom  GBR  1998          6.277368
# 6369  United Kingdom  GBR  1999          6.288063
# 6370  United Kingdom  GBR  2000          6.281344
# 6371  United Kingdom  GBR  2001          6.269377
# 6372  United Kingdom  GBR  2002          6.259442
# 6373  United Kingdom  GBR  2003          6.247951
# 6374  United Kingdom  GBR  2004          6.219039
# 6375  United Kingdom  GBR  2005          6.200892
# 6376  United Kingdom  GBR  2006          6.193433
# 6377  United Kingdom  GBR  2007          6.178852
# 6378  United Kingdom  GBR  2008          6.174013
# 6379  United Kingdom  GBR  2009          6.151082
# 6380  United Kingdom  GBR  2010          6.137737
# 6381  United Kingdom  GBR  2011          6.119607
# 6382  United Kingdom  GBR  2012          6.108550
# 6383  United Kingdom  GBR  2013          6.115762
# 6384  United Kingdom  GBR  2014          6.114625
# 6385  United Kingdom  GBR  2015          6.125289
# 6386  United Kingdom  GBR  2016          6.137610
# 6387  United Kingdom  GBR  2017          6.142092
# 6388  United Kingdom  GBR  2018          6.176326
# 6389  United Kingdom  GBR  2019          6.233144

# %%
import mysql.connector as conn
from sqlalchemy import create_engine

# %%
str_conn = 'mysql+pymysql://root:edgarahmed@localhost:3306/proyecto_cancer'


cursor = create_engine(str_conn)

# %%
cursor
# Out:
# Engine(mysql+pymysql://root:***@localhost:3306/proyecto_cancer)

# %%
df_cases_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 120 entries, 2100 to 6419
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Country           120 non-null    object
#  1   Code              120 non-null    object
#  2   Year              120 non-null    int64
#  3   Number_cases_100  120 non-null    float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 4.7+ KB

# %%
df_cases_4_sp.to_sql(name='cancer_cases_sp', # nombre de la tabla
            con=cursor,          # conexion al servidor
            if_exists='append',  # reemplaza la tabla si existe
            index=False
)
# Out:
# 30

# %%
df_cases_4_fr.to_sql(name='cancer_cases_fr', # nombre de la tabla
            con=cursor,          # conexion al servidor
            if_exists='append',  # reemplaza la tabla si existe
            index=False
)
# Out:
# 30

# %%
df_cases_4_uk.to_sql(name='cancer_cases_uk', # nombre de la tabla
            con=cursor,          # conexion al servidor
            if_exists='append',  # reemplaza la tabla si existe
            index=False
)
# Out:
# 30

# %%
df_cases_4_usa.to_sql(name='cancer_cases_usa', # nombre de la tabla
            con=cursor,          # conexion al servidor
            if_exists='append',  # reemplaza la tabla si existe
            index=False
)
# Out:
# 30
