# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select   # seleccion de un dropdown
import time
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver import ActionChains #para mover las barras
import asyncio as asy
from tqdm.notebook import tqdm
import numpy as np  #Numpy
import matplotlib.pyplot as plt #graficas

# %%
df_1 = pd.read_csv('/Users/edgarahmed/Desktop/ironhack/semana_4/dia_5/w4-project_ETL/data/share-of-population-with-cancer-types.csv')


df_1
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1990
# 1     Afghanistan  AFG  1991
# 2     Afghanistan  AFG  1992
# 3     Afghanistan  AFG  1993
# 4     Afghanistan  AFG  1994
# ...           ...  ...   ...
# 6775     Zimbabwe  ZWE  2015
# 6776     Zimbabwe  ZWE  2016
# 6777     Zimbabwe  ZWE  2017
# 6778     Zimbabwe  ZWE  2018
# 6779     Zimbabwe  ZWE  2019
#
#       Current number of cases of liver cancer per 100 people, in both sexes aged age-standardized  \
# 0                                              0.011680
# 1                                              0.011660
# 2                                              0.011644
# 3                                              0.011637
# 4                                              0.011641
# ...                                                 ...
# 6775                                           0.014615
# 6776                                           0.014442
# ...

# %%
df_types = df_1.copy()

df_types
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1990
# 1     Afghanistan  AFG  1991
# 2     Afghanistan  AFG  1992
# 3     Afghanistan  AFG  1993
# 4     Afghanistan  AFG  1994
# ...           ...  ...   ...
# 6775     Zimbabwe  ZWE  2015
# 6776     Zimbabwe  ZWE  2016
# 6777     Zimbabwe  ZWE  2017
# 6778     Zimbabwe  ZWE  2018
# 6779     Zimbabwe  ZWE  2019
#
#       Current number of cases of liver cancer per 100 people, in both sexes aged age-standardized  \
# 0                                              0.011680
# 1                                              0.011660
# 2                                              0.011644
# 3                                              0.011637
# 4                                              0.011641
# ...                                                 ...
# 6775                                           0.014615
# 6776                                           0.014442
# ...

# %%
df_types.columns
# Out:
# Index(['Entity', 'Code', 'Year',
#        'Current number of cases of liver cancer per 100 people, in both sexes aged age-standardized',
#        'Current number of cases of kidney cancer per 100 people, in both sexes aged age-standardized',
#        'Current number of cases of larynx cancer per 100 people, in both sexes aged age-standardized',
#        'Current number of cases of breast cancer per 100 people, in both sexes aged age-standardized',
#        'Current number of cases of thyroid cancer per 100 people, in both sexes aged age-standardized',
#        'Current number of cases of bladder cancer per 100 people, in both sexes aged age-standardized',
#        'Current number of cases of uterine cancer per 100 people, in both sexes aged age-standardized',
#        'Current number of cases of ovarian cancer per 100 people, in both sexes aged age-standardized',
#        'Current number of cases of stomach cancer per 100 people, in both sexes aged age-standardized',
# ...

# %%
new_col_name = ['Country', 'Code', 'Year',
       'liver_cancer_per_100',
       'kidney_cancer_per_100',
       'larynx_cancer_per_100',
       'breast_cancer_per_100',
       'thyroid_cancer_per_100',
       'bladder_cancer_per_100',
       'uterine_cancer_per_100',
       'ovarian_cancer_per_100',
       'stomach_cancer_per_100',
       'prostate_cancer_per_100',
       'cervical_cancer_per_100',
       'testicular_cancer_per_100',
       'pancreatic_cancer_per_100',
       'esophageal_cancer_per_100',
       'nasopharynx_cancer_per_100',
       'colon_and_rectum_cancer_per_100',
       'non-melanoma_skin_cancer_per_100',
       'lip_oral_cavity_cancer_per_100',
       'tracheal_lung cancer per 100',
       'brain_cancer per 100',
       'gallbladder_biliary_cancer_per_100']

# %%
df_types.columns = new_col_name

df_types
# Out:
#           Country Code  Year  liver_cancer_per_100  kidney_cancer_per_100  \
# 0     Afghanistan  AFG  1990              0.011680               0.003447
# 1     Afghanistan  AFG  1991              0.011660               0.003327
# 2     Afghanistan  AFG  1992              0.011644               0.003259
# 3     Afghanistan  AFG  1993              0.011637               0.003255
# 4     Afghanistan  AFG  1994              0.011641               0.003224
# ...           ...  ...   ...                   ...                    ...
# 6775     Zimbabwe  ZWE  2015              0.014615               0.002949
# 6776     Zimbabwe  ZWE  2016              0.014442               0.003070
# 6777     Zimbabwe  ZWE  2017              0.014290               0.003161
# 6778     Zimbabwe  ZWE  2018              0.014133               0.003237
# 6779     Zimbabwe  ZWE  2019              0.013950               0.003291
#
#       larynx_cancer_per_100  breast_cancer_per_100  thyroid_cancer_per_100  \
# ...

# %%
df_types_4 = df_types[df_types['Code'].isin(['ESP', 'FRA', 'USA', 'GBR'])]

df_types_4
# Out:
#             Country Code  Year  liver_cancer_per_100  kidney_cancer_per_100  \
# 2100         France  FRA  1990              0.005736               0.028468
# 2101         France  FRA  1991              0.006158               0.029284
# 2102         France  FRA  1992              0.006558               0.030396
# 2103         France  FRA  1993              0.006922               0.031547
# 2104         France  FRA  1994              0.007235               0.032080
# ...             ...  ...   ...                   ...                    ...
# 6415  United States  USA  2015              0.007990               0.071927
# 6416  United States  USA  2016              0.008116               0.072447
# 6417  United States  USA  2017              0.008250               0.072256
# 6418  United States  USA  2018              0.008360               0.072613
# 6419  United States  USA  2019              0.008475               0.072749
#
# ...

# %%
df_types_4_sp = df_types_4[df_types_4['Code'].isin(['ESP'])]

df_types_4_sp
# Out:
#      Country Code  Year  liver_cancer_per_100  kidney_cancer_per_100  \
# 5670   Spain  ESP  1990              0.004364               0.025864
# 5671   Spain  ESP  1991              0.004677               0.027533
# 5672   Spain  ESP  1992              0.005009               0.028772
# 5673   Spain  ESP  1993              0.005354               0.030281
# 5674   Spain  ESP  1994              0.005704               0.031346
# 5675   Spain  ESP  1995              0.006054               0.032348
# 5676   Spain  ESP  1996              0.006442               0.033413
# 5677   Spain  ESP  1997              0.006882               0.034157
# 5678   Spain  ESP  1998              0.007340               0.035420
# 5679   Spain  ESP  1999              0.007778               0.036641
# 5680   Spain  ESP  2000              0.008158               0.036589
# 5681   Spain  ESP  2001              0.008534               0.036908
# 5682   Spain  ESP  2002              0.008946               0.037372
# ...

# %%
df_types_4_fr = df_types_4[df_types_4['Code'].isin(['FRA'])]

df_types_4_fr
# Out:
#      Country Code  Year  liver_cancer_per_100  kidney_cancer_per_100  \
# 2100  France  FRA  1990              0.005736               0.028468
# 2101  France  FRA  1991              0.006158               0.029284
# 2102  France  FRA  1992              0.006558               0.030396
# 2103  France  FRA  1993              0.006922               0.031547
# 2104  France  FRA  1994              0.007235               0.032080
# 2105  France  FRA  1995              0.007483               0.032334
# 2106  France  FRA  1996              0.007691               0.032985
# 2107  France  FRA  1997              0.007895               0.033647
# 2108  France  FRA  1998              0.008090               0.035190
# 2109  France  FRA  1999              0.008272               0.035832
# 2110  France  FRA  2000              0.008435               0.035737
# 2111  France  FRA  2001              0.008587               0.036779
# 2112  France  FRA  2002              0.008735               0.037833
# ...

# %%
df_types_4_usa = df_types_4[df_types_4['Code'].isin(['USA'])]

df_types_4_usa
# Out:
#             Country Code  Year  liver_cancer_per_100  kidney_cancer_per_100  \
# 6390  United States  USA  1990              0.002928               0.063557
# 6391  United States  USA  1991              0.003132               0.064949
# 6392  United States  USA  1992              0.003346               0.066584
# 6393  United States  USA  1993              0.003566               0.069388
# 6394  United States  USA  1994              0.003785               0.071165
# 6395  United States  USA  1995              0.004000               0.072707
# 6396  United States  USA  1996              0.004232               0.072850
# 6397  United States  USA  1997              0.004495               0.073022
# 6398  United States  USA  1998              0.004766               0.073175
# 6399  United States  USA  1999              0.005024               0.073226
# 6400  United States  USA  2000              0.005248               0.074117
# ...

# %%
df_types_4_uk = df_types_4[df_types_4['Code'].isin(['GBR'])]

df_types_4_uk
# Out:
#              Country Code  Year  liver_cancer_per_100  kidney_cancer_per_100  \
# 6360  United Kingdom  GBR  1990              0.002705               0.030310
# 6361  United Kingdom  GBR  1991              0.002766               0.031106
# 6362  United Kingdom  GBR  1992              0.002842               0.031954
# 6363  United Kingdom  GBR  1993              0.002931               0.033718
# 6364  United Kingdom  GBR  1994              0.003029               0.034412
# 6365  United Kingdom  GBR  1995              0.003130               0.035880
# 6366  United Kingdom  GBR  1996              0.003255               0.036603
# 6367  United Kingdom  GBR  1997              0.003417               0.037342
# 6368  United Kingdom  GBR  1998              0.003606               0.038605
# 6369  United Kingdom  GBR  1999              0.003810               0.039605
# 6370  United Kingdom  GBR  2000              0.004019               0.040076
# ...

# %% [markdown]
# ## Importación a SQL

# %%
import mysql.connector as conn
from sqlalchemy import create_engine

# %%
str_conn = 'mysql+pymysql://root:edgarahmed@localhost:3306/proyecto_cancer'


cursor = create_engine(str_conn)

# %%
df_types_4_sp.to_sql(name='cancer_types_sp', # nombre de la tabla
            con=cursor,          # conexion al servidor
            if_exists='append',  # reemplaza la tabla si existe
            index=False
)
# Out:
# 30

# %%
df_types_4_fr.to_sql(name='cancer_types_fr', # nombre de la tabla
            con=cursor,          # conexion al servidor
            if_exists='append',  # reemplaza la tabla si existe
            index=False
)
# Out:
# 30

# %%
df_types_4_uk.to_sql(name='cancer_types_uk', # nombre de la tabla
            con=cursor,          # conexion al servidor
            if_exists='append',  # reemplaza la tabla si existe
            index=False
)
# Out:
# 30

# %%
df_types_4_usa.to_sql(name='cancer_types_usa', # nombre de la tabla
            con=cursor,          # conexion al servidor
            if_exists='append',  # reemplaza la tabla si existe
            index=False
)
# Out:
# 30
