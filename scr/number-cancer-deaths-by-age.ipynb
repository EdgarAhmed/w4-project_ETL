# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select   # seleccion de un dropdown
import time
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver import ActionChains #para mover las barras
import asyncio as asy
from tqdm.notebook import tqdm
import numpy as np  #Numpy
import matplotlib.pyplot as plt #graficas
import mysql.connector as conn
from sqlalchemy import create_engine

# %%
df_1 = pd.read_csv('/Users/edgarahmed/Desktop/ironhack/semana_4/dia_5/w4-project_ETL/data/cancer-deaths-by-age.csv')


df_1
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1990
# 1     Afghanistan  AFG  1991
# 2     Afghanistan  AFG  1992
# 3     Afghanistan  AFG  1993
# 4     Afghanistan  AFG  1994
# ...           ...  ...   ...
# 6835     Zimbabwe  ZWE  2015
# 6836     Zimbabwe  ZWE  2016
# 6837     Zimbabwe  ZWE  2017
# 6838     Zimbabwe  ZWE  2018
# 6839     Zimbabwe  ZWE  2019
#
#       Deaths - Neoplasms - Sex: Both - Age: 70+ years (Number)  \
# 0                                                  3346
# 1                                                  3382
# 2                                                  3427
# 3                                                  3489
# 4                                                  3554
# ...                                                 ...
# 6835                                               3488
# 6836                                               3573
# 6837                                               3654
# ...

# %%
df_number = df_1.copy()

df_number
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1990
# 1     Afghanistan  AFG  1991
# 2     Afghanistan  AFG  1992
# 3     Afghanistan  AFG  1993
# 4     Afghanistan  AFG  1994
# ...           ...  ...   ...
# 6835     Zimbabwe  ZWE  2015
# 6836     Zimbabwe  ZWE  2016
# 6837     Zimbabwe  ZWE  2017
# 6838     Zimbabwe  ZWE  2018
# 6839     Zimbabwe  ZWE  2019
#
#       Deaths - Neoplasms - Sex: Both - Age: 70+ years (Number)  \
# 0                                                  3346
# 1                                                  3382
# 2                                                  3427
# 3                                                  3489
# 4                                                  3554
# ...                                                 ...
# 6835                                               3488
# 6836                                               3573
# 6837                                               3654
# ...

# %%
df_number.columns
# Out:
# Index(['Entity', 'Code', 'Year',
#        'Deaths - Neoplasms - Sex: Both - Age: 70+ years (Number)',
#        'Deaths - Neoplasms - Sex: Both - Age: 50-69 years (Number)',
#        'Deaths - Neoplasms - Sex: Both - Age: 15-49 years (Number)',
#        'Deaths - Neoplasms - Sex: Both - Age: 5-14 years (Number)',
#        'Deaths - Neoplasms - Sex: Both - Age: Under 5 (Number)'],
#       dtype='object')

# %%
new_col_name =['Country', 'Code', 'Year',
       'Deaths - Neoplasms - Sex: Both - Age: 70+ years (Number)',
       'Deaths - Neoplasms - Sex: Both - Age: 50-69 years (Number)',
       'Deaths - Neoplasms - Sex: Both - Age: 15-49 years (Number)',
       'Deaths - Neoplasms - Sex: Both - Age: 5-14 years (Number)',
       'Deaths - Neoplasms - Sex: Both - Age: Under 5 (Number)']

# %%
df_number.columns = new_col_name

df_number
# Out:
#           Country Code  Year  \
# 0     Afghanistan  AFG  1990
# 1     Afghanistan  AFG  1991
# 2     Afghanistan  AFG  1992
# 3     Afghanistan  AFG  1993
# 4     Afghanistan  AFG  1994
# ...           ...  ...   ...
# 6835     Zimbabwe  ZWE  2015
# 6836     Zimbabwe  ZWE  2016
# 6837     Zimbabwe  ZWE  2017
# 6838     Zimbabwe  ZWE  2018
# 6839     Zimbabwe  ZWE  2019
#
#       Deaths - Neoplasms - Sex: Both - Age: 70+ years (Number)  \
# 0                                                  3346
# 1                                                  3382
# 2                                                  3427
# 3                                                  3489
# 4                                                  3554
# ...                                                 ...
# 6835                                               3488
# 6836                                               3573
# 6837                                               3654
# ...

# %%
df_number_4 = df_number[df_number['Code'].isin(['ESP', 'FRA', 'USA', 'GBR'])]

df_number_4
# Out:
#             Country Code  Year  \
# 2100         France  FRA  1990
# 2101         France  FRA  1991
# 2102         France  FRA  1992
# 2103         France  FRA  1993
# 2104         France  FRA  1994
# ...             ...  ...   ...
# 6355  United States  USA  2015
# 6356  United States  USA  2016
# 6357  United States  USA  2017
# 6358  United States  USA  2018
# 6359  United States  USA  2019
#
#       Deaths - Neoplasms - Sex: Both - Age: 70+ years (Number)  \
# 2100                                              80168
# 2101                                              81889
# 2102                                              83640
# 2103                                              85536
# 2104                                              86439
# ...                                                 ...
# 6355                                             409905
# 6356                                             416357
# 6357                                             425507
# ...

# %%
df_number_4_sp = df_number_4[df_number_4['Code'].isin(['ESP'])]

df_number_4_sp
# Out:
#      Country Code  Year  \
# 5610   Spain  ESP  1990
# 5611   Spain  ESP  1991
# 5612   Spain  ESP  1992
# 5613   Spain  ESP  1993
# 5614   Spain  ESP  1994
# 5615   Spain  ESP  1995
# 5616   Spain  ESP  1996
# 5617   Spain  ESP  1997
# 5618   Spain  ESP  1998
# 5619   Spain  ESP  1999
# 5620   Spain  ESP  2000
# 5621   Spain  ESP  2001
# 5622   Spain  ESP  2002
# 5623   Spain  ESP  2003
# 5624   Spain  ESP  2004
# 5625   Spain  ESP  2005
# 5626   Spain  ESP  2006
# 5627   Spain  ESP  2007
# 5628   Spain  ESP  2008
# 5629   Spain  ESP  2009
# 5630   Spain  ESP  2010
# 5631   Spain  ESP  2011
# 5632   Spain  ESP  2012
# 5633   Spain  ESP  2013
# 5634   Spain  ESP  2014
# 5635   Spain  ESP  2015
# 5636   Spain  ESP  2016
# 5637   Spain  ESP  2017
# 5638   Spain  ESP  2018
# 5639   Spain  ESP  2019
#
#       Deaths - Neoplasms - Sex: Both - Age: 70+ years (Number)  \
# 5610                                              43534
# 5611                                              44835
# ...

# %%
df_number_4_fr = df_number_4[df_number_4['Code'].isin(['FRA'])]

df_number_4_fr
# Out:
#      Country Code  Year  \
# 2100  France  FRA  1990
# 2101  France  FRA  1991
# 2102  France  FRA  1992
# 2103  France  FRA  1993
# 2104  France  FRA  1994
# 2105  France  FRA  1995
# 2106  France  FRA  1996
# 2107  France  FRA  1997
# 2108  France  FRA  1998
# 2109  France  FRA  1999
# 2110  France  FRA  2000
# 2111  France  FRA  2001
# 2112  France  FRA  2002
# 2113  France  FRA  2003
# 2114  France  FRA  2004
# 2115  France  FRA  2005
# 2116  France  FRA  2006
# 2117  France  FRA  2007
# 2118  France  FRA  2008
# 2119  France  FRA  2009
# 2120  France  FRA  2010
# 2121  France  FRA  2011
# 2122  France  FRA  2012
# 2123  France  FRA  2013
# 2124  France  FRA  2014
# 2125  France  FRA  2015
# 2126  France  FRA  2016
# 2127  France  FRA  2017
# 2128  France  FRA  2018
# 2129  France  FRA  2019
#
#       Deaths - Neoplasms - Sex: Both - Age: 70+ years (Number)  \
# 2100                                              80168
# 2101                                              81889
# ...

# %%
df_number_4_usa = df_number_4[df_number_4['Code'].isin(['USA'])]

df_number_4_usa
# Out:
#             Country Code  Year  \
# 6330  United States  USA  1990
# 6331  United States  USA  1991
# 6332  United States  USA  1992
# 6333  United States  USA  1993
# 6334  United States  USA  1994
# 6335  United States  USA  1995
# 6336  United States  USA  1996
# 6337  United States  USA  1997
# 6338  United States  USA  1998
# 6339  United States  USA  1999
# 6340  United States  USA  2000
# 6341  United States  USA  2001
# 6342  United States  USA  2002
# 6343  United States  USA  2003
# 6344  United States  USA  2004
# 6345  United States  USA  2005
# 6346  United States  USA  2006
# 6347  United States  USA  2007
# 6348  United States  USA  2008
# 6349  United States  USA  2009
# 6350  United States  USA  2010
# 6351  United States  USA  2011
# 6352  United States  USA  2012
# 6353  United States  USA  2013
# 6354  United States  USA  2014
# 6355  United States  USA  2015
# 6356  United States  USA  2016
# 6357  United States  USA  2017
# 6358  United States  USA  2018
# ...

# %%
df_number_4_uk = df_number_4[df_number_4['Code'].isin(['GBR'])]

df_number_4_uk
# Out:
#              Country Code  Year  \
# 6300  United Kingdom  GBR  1990
# 6301  United Kingdom  GBR  1991
# 6302  United Kingdom  GBR  1992
# 6303  United Kingdom  GBR  1993
# 6304  United Kingdom  GBR  1994
# 6305  United Kingdom  GBR  1995
# 6306  United Kingdom  GBR  1996
# 6307  United Kingdom  GBR  1997
# 6308  United Kingdom  GBR  1998
# 6309  United Kingdom  GBR  1999
# 6310  United Kingdom  GBR  2000
# 6311  United Kingdom  GBR  2001
# 6312  United Kingdom  GBR  2002
# 6313  United Kingdom  GBR  2003
# 6314  United Kingdom  GBR  2004
# 6315  United Kingdom  GBR  2005
# 6316  United Kingdom  GBR  2006
# 6317  United Kingdom  GBR  2007
# 6318  United Kingdom  GBR  2008
# 6319  United Kingdom  GBR  2009
# 6320  United Kingdom  GBR  2010
# 6321  United Kingdom  GBR  2011
# 6322  United Kingdom  GBR  2012
# 6323  United Kingdom  GBR  2013
# 6324  United Kingdom  GBR  2014
# 6325  United Kingdom  GBR  2015
# 6326  United Kingdom  GBR  2016
# 6327  United Kingdom  GBR  2017
# ...

# %% [markdown]
# ## Importación a SQL

# %%
import mysql.connector as conn
from sqlalchemy import create_engine

# %%
str_conn = 'mysql+pymysql://root:edgarahmed@localhost:3306/proyecto_cancer'


cursor = create_engine(str_conn)

# %%
df_number_4_sp.to_sql(name='cancer_deaths_by_age_sp', # nombre de la tabla
            con=cursor,          # conexion al servidor
            if_exists='append',  # reemplaza la tabla si existe
            index=False
           )
# Out:
# 30

# %%
df_number_4_fr.to_sql(name='cancer_deaths_by_age_fr', # nombre de la tabla
            con=cursor,          # conexion al servidor
            if_exists='append',  # reemplaza la tabla si existe
            index=False
           )
# Out:
# 30

# %%
df_number_4_uk.to_sql(name='cancer_deaths_by_age_uk', # nombre de la tabla
            con=cursor,          # conexion al servidor
            if_exists='append',  # reemplaza la tabla si existe
            index=False
           )
# Out:
# 30

# %%
df_number_4_usa.to_sql(name='cancer_deaths_by_age_usa', # nombre de la tabla
            con=cursor,          # conexion al servidor
            if_exists='append',  # reemplaza la tabla si existe
            index=False
           )
# Out:
# 30
